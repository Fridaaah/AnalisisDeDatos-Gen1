# %% [markdown]
# # Visualización de Datos

# %%
# %pip install matplotlib

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Out:
# ...
#   Using cached matplotlib-3.10.3-cp313-cp313-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached contourpy-1.3.2-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.58.0-cp313-cp313-win_amd64.whl.metadata (106 kB)
# ...
#   Using cached kiwisolver-1.4.8-cp313-cp313-win_amd64.whl.metadata (6.3 kB)
# ...
#   Using cached pillow-11.2.1-cp313-cp313-win_amd64.whl.metadata (9.1 kB)
# ...
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# ...
# Using cached matplotlib-3.10.3-cp313-cp313-win_amd64.whl (8.1 MB)
# Using cached contourpy-1.3.2-cp313-cp313-win_amd64.whl (223 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.58.0-cp313-cp313-win_amd64.whl (2.2 MB)
# Using cached kiwisolver-1.4.8-cp313-cp313-win_amd64.whl (71 kB)
# Using cached pillow-11.2.1-cp313-cp313-win_amd64.whl (2.7 MB)
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# ...
#
# ...

# %% [markdown]
# ## Bases

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

plt.plot(x, y, color="purple", marker="o", linestyle="--")
plt.title("Mi primer grafico")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.grid(True)

# %% [markdown]
# ## EJES

# %%
plt.plot(x, y)

# %%
plt.xlim(0, 6)
plt.ylim(0, 12)
# Out:
# (0.0, 12.0)

# %%
plt.xticks([1, 2, 3, 4, 5], ["uno", "dos", "tres", "cuatro", "cinco"])
plt.yticks([0, 5, 10])
# Out:
# ([<matplotlib.axis.YTick at 0x1773149b250>,
# ...
#  [Text(0, 0, '0'), Text(0, 5, '5'), Text(0, 10, '10')])

# %%
plt.grid(True, linestyle="--", alpha=0.5)

# %%
## estilo a los ejes
ax = plt.gca() ## obtener los ejes actuales

ax.spines["top"].set_color("red") ## cambiar color del borde superior
ax.spines["bottom"].set_color("blue") ## cambiar color del borde inferior

ax.spines["right"].set_visible(False) ## ocultar borde derecho

# %% [markdown]
# ## Tipos de Graficos

# %% [markdown]
# ### Dispersión (Scatter)

# %%
horas = [1, 2, 3, 4, 5]
calificaciones = [2, 3, 5, 7, 11]
plt.scatter(horas, calificaciones, s=300, c="green", marker="+")
plt.title("Calificaciones por horas de estudio")
# Out:
# Text(0.5, 1.0, 'Calificaciones por horas de estudio')

# %% [markdown]
# ### Barras

# %%
panes = ["concha", "cuernito", "dona"]
ventas = [56, 90, 45]

plt.bar(panes, ventas)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ### Pastel

# %%
etiquetas = ["concha", "cuernito", "dona", "brownie"]
valores = [56, 90, 45, 30]
explotar = (0, 0, 0 , 0.3) ## separar las rebanadas
colores = ["#ff9999", "#66b3ff", "#99ff99", "#ffcc99"]

plt.pie(valores, labels=etiquetas, explode=explotar, colors=colores) 
plt.title("Ventas de panes")
# Out:
# Text(0.5, 1.0, 'Ventas de panes')
